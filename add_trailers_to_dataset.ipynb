# %%
import pandas as pd

# %%
df_trailers = pd.read_csv('to_download_trailers.csv')
df_trailers.head()
# Out:
#      imdb_id                       trailer
# 0  tt0035423  https://youtu.be/6FeyhlLZYrg
# 1  tt0113026  https://youtu.be/K9Da-XCJvYM
# 2  tt0113092  https://youtu.be/sc94f2SG0DM
# 3  tt0118589  https://youtu.be/QaKxGrajnzY
# 4  tt0118694  https://youtu.be/dWVDZ98AFhI

# %%
df = pd.read_csv('movie_dataset.csv')
df.head()
# Out:
#    Unnamed: 0                              genres     id    imdb_id  \
# 0           0   ['Animation', 'Comedy', 'Family']    862  tt0114709
# 1           1  ['Adventure', 'Fantasy', 'Family']   8844  tt0113497
# 2           2               ['Romance', 'Comedy']  15602  tt0113228
# 3           3      ['Comedy', 'Drama', 'Romance']  31357  tt0114885
# 4           4                          ['Comedy']  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# ...

# %%
df.shape
# Out:
# (18875, 25)

# %%
df = df.merge(df_trailers[['imdb_id', 'trailer']], on=['imdb_id'], how='inner')
df.head()
# Out:
#    Unnamed: 0                                    genres     id    imdb_id  \
# 0        2232  ['Drama', 'Action', 'Thriller', 'Crime']  19457  tt0138946
# 1        2543                                ['Comedy']  10471  tt0195945
# 2        2553             ['Comedy', 'Drama', 'Family']  17908  tt0156812
# 3        2571  ['Comedy', 'Drama', 'Family', 'Romance']  10472  tt0186975
# 4        2575                       ['Drama', 'Comedy']  75531  tt0141399
#
#   original_language   original_title  \
# 0                en        The Yards
# 1                en      Next Friday
# 2                en      My Dog Skip
# 3                en      Down to You
# 4                de  Isn't She Great
#
#                                             overview  \
# 0  In the rail yards of Queens, contractors repai...
# 1  Ice Cube returns as Craig Jones, a streetwise ...
# 2  A shy boy is unable to make friends in Yazoo C...
# 3  College coeds in New York City, Al, the son of...
# ...

# %%
df.shape
# Out:
# (6308, 26)

# %%
df.to_csv('./movie_dataset.csv')

# %%
df[['imdb_id', 'trailer']].to_csv('')
# Out:
#         imdb_id                       trailer
# 0     tt0138946  https://youtu.be/udKtT5xkF_0
# 1     tt0195945  https://youtu.be/mKepqz19Qb0
# 2     tt0156812  https://youtu.be/KakRQzu6S3g
# 3     tt0186975  https://youtu.be/1CKVi7AibI8
# 4     tt0141399  https://youtu.be/MuKuIp8sNvw
# ...         ...                           ...
# 6303  tt5700224  https://youtu.be/jYHlRoADo1w
# 6304  tt5973626  https://youtu.be/_f728vAHmRg
# 6305  tt3062096  https://youtu.be/vXXAWJ4NCRo
# 6306  tt4361050  https://youtu.be/MJIcZGEjjwo
# 6307  tt1679335  https://youtu.be/PXrm5eU6HtY
#
# [6308 rows x 2 columns]
